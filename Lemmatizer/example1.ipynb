# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from nltk) (8.5.0)
# Requirement already satisfied: joblib in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from nltk) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from nltk) (2026.9.10)
# Requirement already satisfied: tqdm in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from nltk) (4.70.1)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from joblib->nltk) (3.1.2)
# Requirement already satisfied: colorama in C:\Users\Subhash Adireddy\AppData\Roaming\Python\Python314\site-packages (from tqdm->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
words = ["eating","eats","eat","writing","write","writes","go","goes","going"]

# %%
## verb
for word in words:
    print(word+"---"+ lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating---eat
# eats---eat
# eat---eat
# writing---write
# write---write
# writes---write
# go---go
# goes---go
# going---go

# %%
## NOUN
for word in words:
    print(word+"---"+ lemmatizer.lemmatize(word,pos='n'))
# Out:
# eating---eating
# eats---eats
# eat---eat
# writing---writing
# write---write
# writes---writes
# go---go
# goes---go
# going---going

# %%
lemmatizer.lemmatize("goes")
# Out:
# 'go'
