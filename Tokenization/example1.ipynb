# %%
import sys
# !{sys.executable} -m pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

# %%
# Tokenization - sentence into paragraph
from nltk.tokenize import sent_tokenize

corpus = 'Hello welcome to AVS NLP practice session. Please focus on it.'

print(sent_tokenize(corpus))
